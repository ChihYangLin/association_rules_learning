# %% [markdown]
# # 載入模組

# %%
# import module
import pandas as pd
import numpy as np
from apyori import apriori

# %%
# import retailer data
data_df = pd.read_csv('transaction_records.csv', encoding='utf-8')
data_df.head()
# Out:
#    CustomerID StockCode          ProductName
# 0           1     22664           龍口埔里水粉400g
# 1           1     22294  康乃馨夜用特長超薄蝶型(14片x4包)
# 2           1     21385       家樂福哥斯大黎加濾泡式咖啡粉
# 3           1     21107                 木柄菜匙
# 4           1     22379          美琪天然T3抗菌洗手乳

# %% [markdown]
# # 做出Apriori需要的雙list資料型態，一個顧客購買的商品，包在一個list裡面

# %%
# 做顧客購物清單的雙層List 例如:[[A,C],[B,D,E],[A,F]...]
user_product_df = data_df.groupby('CustomerID').agg({'ProductName': lambda x : ','.join(x).split(',')})
record = user_product_df['ProductName'].tolist()
record[:1]
# Out:
# [['龍口埔里水粉400g',
#   '康乃馨夜用特長超薄蝶型(14片x4包)',
#   '家樂福哥斯大黎加濾泡式咖啡粉',
#   '木柄菜匙',
#   '美琪天然T3抗菌洗手乳',
#   '康寶全新鮮味炒手素食500g',
#   'Paldo金炸醬麵(包)203gx4',
#   '宜而爽男童羅紋短袖圓領衫-28',
#   '歐邁福麵包餅乾香蒜奶油口味-300g',
#   'Jordan清新水果味兒童牙膏(6-12歲)75ml',
#   '員山農會養生豆奶250ml',
#   '奶油小酥餅6入',
#   '安安辣豆瓣醬 130g',
#   'Caravan捲式髮捲(小)',
#   '天然防蹣防蚊保潔墊-雙人加大',
#   '舒適超鋒3刮鬍刀片 4入',
#   '台東關山好米(圓二)9kg',
#   '克潮靈 環保除濕桶補充包-檜木香',
#   '蘇菲極淨肌超薄潔翼日用25cm-16PCx2包',
#   '聲寶YK-W1252B HDMI 1.8m',
#   '馬玉山紫山藥黑豆漿 30克x12',
#   'YS香烤軟雞肉卷 200g',
#   '韓國不倒翁Q拉麵(純粗麵條)110g*5',
#   '天仁茗賞-高山烏龍茶',
#   'MG 專利安全飛盤-螢黃',
#   'Fun Bath 3D沐浴海棉-小馬',
#   '宗家府食堂-韓國芝麻葉',
#   'Binggrae螃蟹餅乾(火辣炒碼口味)',
#   'No Brand黃豆粉韓式年糕風味餅乾-130g',
#   'OP生物分解抗菌立體密封袋 L',
#   'blacklabel BL-9168 16吋立扇',
#   '宗家府泡菜-白菜切塊300g',
#   '蕾妮亞私密肌濕式衛生紙巾-15PC',
#   '【烤肉用品】自然風特選燒烤專用炭精1.8kg',
#   '3M新防蹣水洗枕幼兒型(附枕套)',
#   '靠得住安全瞬吸護墊無香標準型14.5cm-30PCx2',
#   '中祥自然之顏蔬菜蘇打',
#   '【狗食】寶路乾糧雞肉及蔬菜口味3kg',
#   '天生好米嚴選月之米6kg',
#   '原味巡禮野菜餅',
#   '履歷金目鱸魚片(每包約280克)',
#   'keyway名廚標準量水杯600cc',
#   '正安白菜切塊 罐裝',
#   '馬玉山榛果杏仁茶 30克x12',
#   'DL安全棒球',
#   '20公升折疊水箱(台灣製)',
#   '好麗友好多魚餅乾(海苔口味)',
#   '金頂金霸王鹼性電池 3號 AA 18粒裝',
#   '寶宏安柏Light奶素脂肪抹醬',
#   '響鈴靜音鬧鐘 TW-8632-顏色隨機出貨',
#   '登豐丁香魚100g',
#   '明治蘇打餅乾-26gx4',
#   '沙威隆抗菌潔淨沐浴乳茶樹精油',
#   '3M掛鉤替換膠條-中',
#   '【烤肉用品】40CM不鏽鋼梅花夾',
#   '維力素飄香-素紅燒牛肉-85gx5',
#   '家樂福嚴選紅蘿蔔(每袋約600g)',
#   '家樂福抗菌潔膚濕巾',
#   'CLOROX 高樂氏強效除霉劑-473ml',
#   '工研白醋 600ml',
#   '阿華田 減糖巧克力營養麥芽飲品-31gx14',
#   '家樂福超值抗菌濃縮洗衣精',
#   '久代-袋裝爆皮(炸豬皮)50g',
#   '奇檬子馬桶水管泡沫彈-700G',
#   'Trops 5號彩色排球',
#   '【汽車百貨】黑珍珠ECC-99防銹劑',
#   'YS香烤小塊香雞肉 200g',
#   '【露營用品】迷你鋁合金口哨掛環',
#   '台康胡椒肉排(冷藏)(蛋奶素)300g',
#   '多納滋低敏犬狗糧 2.0公斤',
#   '旅行家抗菌防臭 3/4中性休閒襪-灰色',
#   '沙威隆抗菌保濕沐浴乳蘆薈精華',
#   '家樂福即食大燕麥片500g',
#   '雀巢咖啡拿鐵咖啡無添加糖膠囊-164g',
#   '工研烏醋 600g',
#   '王子麵-火鍋/滷味專用50g*5入組',
#   '山寧泰防蹣抗菌記憶枕',
#   '克潮靈吊掛式除濕袋-去霉味-200gx4',
#   '不倒翁辣起司風味拉麵111g x4',
#   '豪記米血糕',
#   '佳德鳳梨酥禮盒12入',
#   '1881防蹣抗菌超柔枕',
#   '台鹽蓓舒美海鹽抗菌洗手露-500ml',
#   '【烤肉用品】自然風特選紅木條炭2.4kg',
#   '香草淨抗菌洗衣皂液',
#   'Swiss Miss牛奶巧克力可可粉280g',
#   'PALDO御膳火辣章魚乾拌麵130g',
#   '馬玉山亞麻籽堅果杏仁飲 28克x10',
#   '微風如沐果香沐浴乳-甜蜜桃-1200g',
#   '雅方古早味梅子冰棒-70gx5',
#   '登豐 蝦皮150g',
#   '登豐 紅豆',
#   '朵蔓清涼舒爽頭皮淨化洗髮精400ml 韓國進口',
#   '威猛先生地板清潔劑清新早晨',
#   '維力素飄香麻辣燙風味麵-90gx5',
#   '花王潤髮乳750ml',
#   '貝納頌三合一咖啡-經典曼特寧',
#   '勝利牌羽球拍握把布3入',
#   '家樂福超值狗乾糧(羊肉風味)3.5',
#   'On The Body 粉紅甜心香水沐浴精',
#   '可彎曲手捏管道疏通器-四爪取物器--顏色隨機出貨',
#   '法國弓箭1.5L微晶炫彩透明鍋',
#   '滿漢大餐麻辣鍋牛肉(碗) 204g',
#   '口蜜牌水蜜桃罐頭825G',
#   '【狗食】西莎低脂火雞與蔬菜狗乾糧1kg',
#   '福華牌沙茶醬(大) 737g',
#   '康朵 白麝香室內香氛擴香膏-120g',
#   '葛莉思犬食--皮膚保健配方2Kg',
#   'CW恐龍造型餅乾-60g',
#   '【火鍋好物】裕國精選豬肉片180g',
#   '日本JB芳香膏',
#   '安心雞-雞里肌肉',
#   '家樂福冷凍黑豬里肌烤肉片(每盒約250克)',
#   '妙管家馬桶自動清潔劑',
#   '西莎餐盒南法野菜燉雞100g6入/組',
#   '履歷去刺虱目魚肚(每包約150克)',
#   'Rober Timms哥倫比亞濾袋咖啡',
#   '家樂福草蝦',
#   '平面糖果襪 6入-彩色',
#   '熊寶貝經典山茶花衣物清新噴霧200ml',
#   '海太天然酵母蘇打餅',
#   '西莎蒸鮮包成犬 低脂雞肉70g',
#   '葛莉思犬罐-牛肉口味 400g',
#   '鴻津太國捲(蛋奶素)-370g',
#   '桂格鮮穀王-野菇多穀飲-26gx10',
#   '雙葉冰棒-紅豆粉粿-67gx5',
#   '簡易實用型烤肉架',
#   '聖光牌純米米粉-素食風味-85g',
#   '麗滋起司餅乾隨手包243g(27gx9)',
#   '皇家榖堡莊園紫米-1kg',
#   '魅尚萱完美修護護髮精油輕盈版',
#   'De Cecco 義大利寬扁細麵-500g',
#   '【寵物用品】DogClub 10mm拉帶+胸背帶-顏色隨機出貨',
#   '美藝舞Q年糕條-300g',
#   '蘇菲超熟睡夜用細緻棉柔28cm(16片x3包)',
#   '登豐海帶芽120g',
#   'iGRASS 多功能迷你頸掛風扇-綠色',
#   '家樂福鯛魚片(每包淨重約480克)',
#   '新貴派大格酥鹿耳島抹茶 324g',
#   '李錦記蒜蓉辣椒醬368g',
#   '酥炸豆乳雞翅(1支)',
#   '寶路狗乾糧牛肉口味3Kg',
#   '農心辛拉麵超值包120g x5',
#   '伊萊克斯EBR3216果汁機',
#   '【寵物用品】天然草本驅蚤項圈-犬/貓專用',
#   '咪亞機能貓罐-鮪魚+小魚干口味 160g',
#   '聲寶KB-RF85U紫外線烘碗機',
#   '韓味不二韓國海苔酥(原味)',
#   '盛香珍-無調味核桃仁-140g',
#   '【福和嚴選】紐西蘭愛妃蘋果#30(1每箱約10KG)',
#   '【金豐盛】蒜鹽百里香醃雞胸(每包約170g)',
#   'Coway AP-1216綠淨力空氣清淨機',
#   'GATSBY體用抗菌濕巾大包裝',
#   '旺仔營養小饅頭-原味-60g',
#   '【金豐盛】台味腐乳醃雞翅(每包約300g)',
#   '可瑞絲頭皮去屑止癢舒敏洗髮精600ml 韓國進口',
#   '韓國isLeaf極緻水感保濕面膜22ml-蝸牛',
#   '本家 素藥膳蟲草雞-1200g',
#   'Laundrin擴香',
#   '經典卡通中童半罩安全帽-水藍色',
#   '【海倫仙度絲】男士根源健髮去屑洗髮乳',
#   '顏新發X福源花生醬太陽餅禮盒10入',
#   '靠得住完美封漏乾爽瞬吸夜用41cm-8PCx2包',
#   '奇美素食熟水餃(全素)-800g',
#   'On The Body SPA沐浴露-經典香',
#   '農心辛辣白菜風味拉麵超值包120g x5',
#   'Fitbit Inspire HR 智能健身手環-黑白色',
#   '雨傘刺繡童襪-灰色',
#   '快車杏仁香脆肉紙-櫻花蝦',
#   '旺德 PC-106 多功能計算機',
#   '味好美白胡椒鹽60g',
#   '愛貓機能餐罐(鮪魚+牛肉)85g',
#   '好麗友ORION預感香烤洋芋片(起司)64g',
#   'PX HDMI-1.2MW HDMI高畫質影音',
#   '家樂福超值綠豆枝仔冰棒-375g',
#   '桂格即沖即食大燕麥片1100g',
#   '蘇菲極淨肌極薄0.1潔翼日用23cm-10PCx3包',
#   '橘之屋 雙面多功能調理砧板',
#   '瑪榭舒適萊卡透氣襪-女(紅)-紅色',
#   '靠得住純白體驗超吸洞夜用超薄(13片x3包)',
#   '星巴克黃金烘焙義式濃縮咖啡膠囊(12顆)',
#   '可伶可俐潔面泡沫慕斯',
#   '英國Gtech 小綠 Multi Plus無線除蹣吸塵器',
#   'SIMPLY GOOD樂事羅勒青醬嫩雞-81g',
#   '家樂福日月紅茶-2.4gx25入',
#   'Sunny Ranch每日堅果隨手包-綜合堅果乾-245g',
#   '【多芬】深層修護潤髮乳',
#   'THOMSON TM-SAL04DA錐磨全自動研磨咖啡機',
#   '農心洋蔥圈(原味)-80g',
#   '立頓檸檬紅茶-250mlx24',
#   '義美美味薄餅夾心-檸檬',
#   'BVD學生中統襪-黑、白二色隨機出貨',
#   '光泉低糖鮮豆漿-936ml',
#   '極品限定美好一天-蘋果牛乳-923ml',
#   '現烤綜合蛋黃酥禮盒8入',
#   '西雅圖極品深焙二合一咖啡',
#   '濟州島大王蔘雞湯1.1KG',
#   '天仁阿薩姆紅茶防潮包-2g*100',
#   '五月花蓬厚柔三層抽取衛生紙-110PCx24',
#   '【Nac Nac】防蹣抗菌嬰兒洗衣精(組合包)',
#   '老太陽堂太陽餅禮盒20入',
#   '【DIY】100分鐘正倒數計時器',
#   'IMPACT成長型護脊書包',
#   '讚岐冷凍烏龍麵',
#   '媚比琳快捷濃捲風防水睫毛膏(黑)',
#   'OP花香環保袋(小)-小蒼蘭',
#   '義美素食水餃(全素)1050g',
#   '【貓食】偉嘉乾貓糧海洋魚類3kg',
#   'BVD1/2細針少女襪 鐵灰',
#   '四神湯(調理用)-140g',
#   '恆順鎮江香醋 550ml',
#   '台灣茶人辦公室正能量-速甘金萱-2gx25',
#   '厚匠#304一體成型撈麵杓',
#   '啵樂樂乳酸飲料-草莓味-235ml',
#   '刷樂專業護理漱口水買超值組-綠茶口味-750mlx2',
#   '李錦記蜜汁烤肉醬 240g',
#   '優得氣炸鍋專用紙20.4cm-15入',
#   '台灣履歷去殼玉米筍(每盒約100克)',
#   '【遠距教學】E-books X46高畫質HDMI影音傳輸線1.2M',
#   '讚岐絹絲細麵',
#   '摩卡厚實茶道紅茶拿鐵-25gx15',
#   '微風如沐沐浴乳-香甜柚-1200g',
#   '【寵物用品】F#2貓砂總動員',
#   '游建好素食肉骨茶(純素)50g',
#   '吳寶春特選四重溪鳳黃酥12入禮盒',
#   '統一鮮蝦麵(包)83gx30',
#   '奇美冷凍叉燒肉包',
#   '韓國釜山白醬魚板炒年糕-300g',
#   '【寵物用品】奇異鹿角S',
#   '【露營用品】Tomato 517五人帳篷/綠',
#   '人體工學伏地挺身器(熨斗型)',
#   '韓國Otaste辣炒年糕冬粉杯-辣炸醬味-128g',
#   '阿奇儂冰沙花生花豆',
#   '台東關山鎮農會良質米2.5kg',
#   '【汽車百貨】YARK小圓弧汽車遮陽簾-2入',
#   '啵樂樂乳酸飲料-藍莓味-235ml',
#   '好神拖 超大平板拖超纖除汙布',
#   'Jelly.B低卡蒟蒻果凍(水蜜桃味)150g',
#   '義美e家小館臘肉炒飯',
#   '綠的藥皂',
#   '大西雅圖記憶舒壓踏墊-灰色',
#   '一度贊-爌肉(碗) 200g*2入/組',
#   '巴黎萊雅完美UV防曬精華SPF50-30ml',
#   '【狗食】寶路乾糧羊肉及蔬菜口味3kg',
#   '喜壽燒素油雞(蛋素)-300g',
#   '雀巢美式鑑賞咖啡補充包-170g',
#   'Sugarlolo低卡蒟蒻果凍-水蜜桃-150ml',
#   '伊藤園TEASTEA蘋果紅茶535ml',
#   '義美手工水餃-豬肉韭菜',
#   '陶華碧老干媽豆鼓油制辣椒210g',
#   'BVD1/4中性休閒襪-黑灰白三色隨機出貨',
#   '77新貴派18片盒裝-濃郁抹茶-252g',
#   '南亞保鮮膜真省包 3支/組',
#   '現烤烏豆沙蛋黃酥禮盒12入',
#   '雅方瑪克冰淇淋-芋頭-500g',
#   '雷達噴霧殺蟲劑-天然尤加利精油-500ml',
#   '英國Barr檸檬風味飲料-330ml',
#   '【火鍋好物】雅方牛肉片',
#   '金蘭烤肉醬 240g',
#   '好一頓狗罐頭(雞肉口味)',
#   '五木特級營養麵條經濟包 2000g',
#   '鋁合金三節避震登山杖-顏色隨機出貨',
#   '米森有機黑糖老薑茶',
#   '家樂福超值狗食罐頭(雞肉風味)',
#   '小熊莊園韓式陶鍋-3公升',
#   '隨緣韓式泡菜湯麵(包)75g',
#   '【寵物用品】WORTH我是細砂',
#   '福樂低脂高鈣牛乳(保久乳)200mlx24',
#   '桂冠成功旗魚丸',
#   '好麗友ORION雞米花脆餅(起司炸雞)81g',
#   '【海倫仙度絲】去屑薄荷舒爽洗髮乳',
#   '元本山味付海苔輕巧包(4切)',
#   '木質純白遙控器收納盒',
#   '韓國鄉村泡菜',
#   '星巴克那堤咖啡膠囊(12顆)',
#   'UCC 3合1珈琲-炭燒拿鐵-17gx12',
#   '【寵物用品】DogClub 8mm拉帶+胸背帶-顏色隨機出貨',
#   '泡舒洗潔精補充包-檸檬-800g',
#   '履歷香菇(每盒約150克)',
#   '維力素飄香麻辣燙風味碗麵-100g',
#   '五月花蓬厚柔三層抽取衛生紙-110PCx72',
#   'LOJEL TAGO TRAVLE後背包-顏色隨機出貨',
#   '龍鳳冷凍金脆薯條400g',
#   '【大家源】微晶按鍵式電陶爐 TCY-3911',
#   '農鮮蜂蜜檸檬水450ml',
#   '家樂福植物性彩色海綿',
#   '家樂福有機黑木耳(每包約200克)',
#   '旺旺岩塚仙貝經濟包',
#   '清淨海櫻花7+洗衣精',
#   '典億蒸氣美顏器SY-302',
#   'Kumsung 韓式辣椒粉(醃泡菜用)',
#   '天然防蹣防蚊健康枕-支撐型',
#   '一粒淨全效洗機粉150g',
#   '樂事香焙洋芋片-嫩煎雞柳-89g',
#   'KASTEL丹麥奶酥餅-340g',
#   '義美凍豆腐260g',
#   '韋恩Flash Brew閃萃拿鐵咖啡-500mlx4',
#   '森活9號養生鍋',
#   '家樂福超值洗潔精5000克',
#   'Kernels爆米花(焦糖奶油起司口味杯裝)45g',
#   '天生好米優質九號米3kg',
#   '美藝辣白菜-900g',
#   '家樂福Active水管疏通劑-1000ml',
#   'Airwaves Super重量包極酷薄荷',
#   '必安住水蒸式白蟻衣魚殺蹣滅蟑',
#   '福樂鈣多多健康牛乳-全脂936ml',
#   '一滴淨防蹣洗衣露補充包',
#   '【烤肉用品】自然風316不鏽鋼方格烤網-大',
#   '伯朗咖啡藍山風味',
#   '【寵物用品】趾甲剪',
#   '【寶寶副食品】韓國 IVENET艾唯倪果乾脆片-蘋果15g',
#   'OP天然茶酚洗手慕絲深層抗菌',
#   'GoPro(8D)HERO8 雙電池充電器+電池',
#   '玻妞LEGEE669掃拖機器人',
#   '米蘭現代茶几-白橡木色',
#   '美國Sweet Baby Rays甜辣烤肉醬',
#   '白博士抗菌洗手乳2kg',
#   '膳府韓國傳統辣椒醬',
#   '金農履歷一等白鷺鷥巡米(圓一)2kg',
#   '保力達蠻牛160 ml',
#   '光泉果汁牛乳-200mlx24',
#   '日本近江水潤維他命C、E防曬噴霧-50g',
#   '妙管家噴霧式芳香劑-清新檸檬-300ml',
#   '皮拉提斯帶',
#   '【烤肉用品】自然風烤肉配件組合包',
#   '家樂福素食海帶芽',
#   '優生防蹣抗菌寶寶洗衣精 2000ml-清新西柚配方',
#   '桂格 奇亞籽麥片-鮮奶紅茶-300g',
#   'LOTTE PEPERO-巧克力夾心棒50g',
#   '熊寶貝衣物香氛袋-清新茉莉-7gX3',
#   '大家源TCY-3730多功能鍋',
#   '光泉全脂保久牛乳-200mlx24',
#   'BVD條紋毛巾底女踝襪(麻酒紅)',
#   '馬玉山黑豆多穀堅果飲 30克x12',
#   '靠得住溫柔宣言輕柔棉日用23cm-12PCx3',
#   '【寵物用品】小次郎鼠籠(S)',
#   '4D溫熱手感按摩墊',
#   '農心香辣海鮮味烏龍麵超值包120g x5',
#   '【烤肉用品】大波浪網',
#   '丹 沙丁鮪魚貓罐-185g',
#   '【烤肉用品】妙管家通用烤肉網',
#   'CJ bibigo 韓式醃烤肉醬(香辣)',
#   'CJ BIBIGO 韓式豆瓣醬(肉沾醬)',
#   '去味大師竹木香補充-淡雅茉莉',
#   'OP花香環保袋(中)-薰衣草',
#   '日式分類附蓋垃圾桶CL42L-顏色隨機出貨',
#   'BVD條紋毛巾底女踝襪(白)',
#   '可麗舒抽取衛生紙-100PCx24包x3袋',
#   '3點1刻經典原味奶茶-20gx15',
#   '【椅子】家居止滑椅-小',
#   '健康廚房經典凱薩醬200ml',
#   '威猛先生深層淨力潔廁凝膠',
#   'Garmin vivofit 4 健身手環-深夜星空',
#   '舒適便利室內童拖鞋-藍色-18cm',
#   '林鳳營鮮奶優格400g',
#   '日系E1優雅活動櫃-附工業輪',
#   'ST夢幻香水果凍芳香劑-閃耀香水-260g',
#   '加好寶經典狗餅乾 300G',
#   '土鳳梨一口酥',
#   '韓國不倒翁OH拉麵125g x4',
#   '檸檬蛋糕禮盒8入',
#   '金蘭剝皮辣椒',
#   'Mestemacher什錦榛果穀片',
#   'BVD條紋毛巾底女踝襪(麻卡其)',
#   'UCC 3合1珈琲-原味拿鐵-18gx12',
#   '可麗舒抽取衛生紙-100PCx24',
#   '義美九層塔蛋餅皮',
#   '韓國米香堅果派(起司)110g',
#   '美琪抗菌皂白麝香6入裝',
#   '韓國家樂氏蔓越莓杏仁穀物脆300g',
#   '扇形無漂白咖啡濾紙 LZB-101-40 40入',
#   '曼秀雷敦 緊緻美肌潤膚乳液-250ml',
#   '伯朗三合一咖啡-焦糖瑪琪朵',
#   '運動家通用瓦斯罐(3入)',
#   '家樂福冷凍黑豬梅花火鍋片(每盒約250克)',
#   '義美手工大水餃- 豬肉高麗菜500g',
#   '米森有機漢方養氣茶',
#   '魅尚萱完美深層修護潤髮乳-680ml',
#   '貝納頌經典拿鐵咖啡Can210ml',
#   'POLI 單耳口杯',
#   '聖美多葡萄乾',
#   '三好履歷台梗九號米(圓三)2.2kg',
#   '【汽車百貨】Michelin 米其林 厲風14+26雙入雨刷',
#   '棕欖香皂-牛奶嫩膚',
#   '麥維他黑朱古力消化餅300g',
#   '連帽浴袍-白色',
#   '一匙靈Attack抗菌EX超濃縮洗衣粉-1.8Kg',
#   'TCS SELFIE-004BK 藍牙自拍神器',
#   '舒適便利室內童拖鞋-桃色-22cm',
#   'Farcent香水胺基酸沐浴露-絲滑白麝香',
#   '【機車百貨】向日葵安全帽撥水劑',
#   '陶華碧老干媽香辣脆油辣椒210g',
#   '悅氏麥仔茶Pet2000ml',
#   '家樂福超值蕃茄肉醬義大利麵-1080g',
#   '光泉冷泡茶茶王烏龍-1235mlx12',
#   '1074款歐風餐椅-胡桃木色',
#   '【免洗餐具】自然風環保植纖飯碗(大)500ml',
#   '【保健食品】台塑生醫兒童金盞花葉黃素嚼錠',
#   '哈根達斯 冰淇淋品脫 抹茶 473ml',
#   '【機車百貨】MOTUL 3100 引擎機油-10W40-(平)',
#   '白蘭強效除蹣過敏洗衣精補充包-1.6Kg',
#   'SAKI番茄汁180ML',
#   '家樂福覆盆子果醬 370g',
#   'SDI-10號釘書針1200BN/1200B',
#   '【雨具】城市風塑膠套裝雨衣-顏色隨機出貨-XXL',
#   '溫柔宣言輕柔棉超夜用超長35cm(8片x3包)',
#   '台灣契作南投國姓竹薑片55g',
#   '慧心犬糧-牛肉成犬配方3Kg',
#   'YS營養雞肉條 360g',
#   '康朵英國梨小蒼蘭香水洗衣精補充包-1800ml',
#   '美國LaCroix西西里檸檬風味氣泡水-355ml',
#   '維他露大蘋果蘇打-2000ml',
#   'On The Body 快樂微風沐浴乳',
#   '犬用野菜消臭軟餅乾120g',
#   '路跑用涼感手機臂套-黑色',
#   '老增壽-無子李鹹',
#   '可瑞絲頭皮控油抗屑勁涼洗髮精600ml 韓國進口',
#   '盛美家草莓果醬-340g',
#   '黑人全亮白極緻沁涼薄荷牙膏',
#   '義美銅鑼燒冰淇淋香草-80gx4',
#   '韓國水協-四角魚板串(5入)',
#   '39吋組裝式鬼斧',
#   'CJ bibigo 韓式醃烤肉醬(原味)',
#   '樂生活三段蓮蓬頭驚爆組',
#   '瑪榭舒適萊卡透氣襪-女-黑色',
#   '達新牌負離子吹風機-TS-7000',
#   '桂冠福州丸',
#   '無塵氏 酒精抗菌擦拭巾80抽',
#   '3M新防蹣水洗枕兒童型(附枕套)',
#   '360度繽紛防漏杯 (藍色) 266ml',
#   'Rober Timms義式濾袋咖啡',
#   'BVD條紋毛巾底女踝襪(黑)',
#   '魅萱完美造型護髮精油',
#   '西莎主廚蒔蘿焗烤菲力牛100g',
#   '呂滋養韌髮蔘層髮膜_清爽型',
#   '卡滋DIY玉米粒',
#   '三好履歷契作有身分證米(圓一)3Kg',
#   '舒味思葡萄柚口味汽水-330mlx4',
#   '賽吉兒菁萃潔浴凝露日用型-100ml',
#   '潔豹炸煮方便鍋(單把)20Cm',
#   '【露營用品】探險家舒適保暖睡袋',
#   '雀巢鷹牌煉奶原味條裝-170g',
#   '依必朗兒童抗菌沐浴乳',
#   '【寵物用品】愛思沛坐立式逗貓棒',
#   'EF 1/2男女休閒襪4入',
#   '簡單工房咖啡紗毛巾3入',
#   '羅蜜歐TC-208N來電顯示有線電話',
#   '好神拖標準型布盤(極細緻布盤)',
#   '烹大師干貝風味調味料40g',
#   '瑪榭腳踝加強直條紋輕護足弓襪-LF-顏色隨機',
#   'Farcent香水胺基酸沐浴露-同名花語',
#   '義美巧克力消化餅',
#   '台榮信州味噌',
#   '大倉池農池上契作栽培米(圓二)6kg',
#   '舒味思伯爵紅茶風味氣泡水500mlx24',
#   '寶被袋免用吸塵器收納組-2入',
#   'ibobomi嬰兒米餅(菠菜味)30g',
#   '立頓茗閒情100％台灣茶-茉莉花茶-100.8g(2.8gx36)',
#   '來一客川辣牛肉-67gx24',
#   'Baseland 日本製專業冰桶7.5L',
#   '辣椒叔叔-茶油剝皮辣椒450g',
#   '無塵氏十字壓紋除塵紙4入組',
#   '【寵物用品】六分皮頸帶',
#   '紅RED S脫脂高鈣牛奶粉 1.5Kg',
#   '伯朗絲絨奶茶-580mlx24',
#   'BVD W跟超低襪口男隱形襪(鐵灰)',
#   '日系E1優雅單門櫃',
#   '日本近江小熊臻效防曬乳液',
#   '品田日居方型4格小物收納盒-藍色',
#   '好神拖輕清拖乾濕兩用刮水拖把-黃色',
#   '王鵬傑曲奇餅乾(原味)',
#   '小磨坊新疆孜然粉 24g',
#   '妮維雅男止汗爽身噴霧-無印乾爽海洋',
#   '超吸力雪尼爾止滑踏墊-顏色隨機出貨',
#   'BVD條紋毛巾底女踝襪(麻天籃)',
#   '桂格鮮榖王鮮蔬多穀飲',
#   '寶多福美食犬餐-牛肉口味-2kg',
#   '雀巢美祿可可球-170g',
#   'muva 輕氛震捶按摩棒',
#   'MPP2345多合一萬國轉接頭-顏色隨機出貨',
#   'OP生物分解抗菌立體密封袋 M',
#   '韓國釜山辣味海鮮炒年糕-250g',
#   '新東陽原味小香腸',
#   'DG舒適條紋女踝襪(黑)',
#   '【園藝】中花槽底盤-顏色隨機出貨',
#   '龍口芝麻醬',
#   '樂天杏仁巧克力棒',
#   '大茂幼筍玻璃瓶 350g',
#   '1881純棉素色毛巾4入',
#   '風采摺合椅39CM-顏色隨機出貨',
#   '好麗友烏龜玉米脆片',
#   '米奇圓墊(圖案隨機出貨)',
#   '【咖啡用品】良燒V02錐形濾紙-無漂白',
#   'EZ-GO純棉免洗褲5入(白)紳士型-L',
#   '成功遠紅外線可調式護腰(M)',
#   'GATSBY 造型髮雕霜-濕潤',
#   '農心爽口海鮮烏龍麵超值包-120gx5',
#   '貝納頌二合一咖啡(經典曼特寧風味)13g X25',
#   '慧心犬糧-羊肉+米口味成犬配方 3kg',
#   'Honeywell HRF-E2-AP濾網(兩入)',
#   '星巴克特選系列-卡布奇諾咖啡(每盒內含4杯)',
#   '金晶蛋(冷藏紅蛋)10粒',
#   '黑人牙膏--茶倍健',
#   '鍋寶燜燒鍋5L-內層304不銹鋼材質',
#   '【寵物用品】F#2活力e倍鼠砂1kg-原味',
#   '美漾直取式收納箱-Q3-0311藍色 36*34*25.3cm',
#   '樹德單層工具箱TB-905',
#   '[植物蛋白素]Beyond meat 未來漢堡排(每包約227g)',
#   '啵樂樂乳酸飲料-蘋果味-235ml',
#   '江原道鯷魚海鮮高湯包-120',
#   'Ora2 Me淨白無瑕牙膏薄荷香',
#   '伯朗曼特寧咖啡2合1',
#   '咪歐貓罐-鮪魚口味 170g',
#   '母子鱷魚一代輕量氣墊y拖男女款-黃色-38',
#   '紅布朗 玉荷包蜂蜜 420g',
#   '韓國水協-魚板辣炒年糕',
#   '【收納】TLR-106 你可6格收納盒-290*238*63mm',
#   '馬玉山五榖米 3Kg',
#   'Targus15.6吋黑石電腦包',
#   '沙威隆清爽抗菌濕巾(88抽/包)',
#   '九陽雙層不鏽鋼快煮壺K15-F1M',
#   '義美檸檬夾心酥經濟包']]

# %% [markdown]
# ### 帶入模組並設定參數:降低運算量並篩選更有效的規則(最小支持度, 最小信賴度, 最小提升度, 規則最大產品數)

# %%
association_rules = apriori(record, min_support=0.03, min_confidence = 0.6, min_lift=4,max_length = 2)

# %% [markdown]
# # 將產出的規則，整理成我們要看的表格

# %%
#做出規則的List
association_results = list(association_rules)

#轉成 Dataframe
association_DF = pd.DataFrame(association_results)
association_DF.head()
# Out:
#                                 items   support  \
# 0         (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273
# 1        (1片/包), 家樂福大比目魚切片(每包淨重約160g)  0.032060
# 2        (2片/包), 家樂福大比目魚切片(每包淨重約400g)  0.030308
# 3  (3點1刻 奶油玉米濃湯-18gx12, UCC 114 即溶咖啡)  0.030308
# 4        (3點1刻經典原味奶茶-20gx15, 讚岐冷凍烏龍麵)  0.074982
#
#                                   ordered_statistics
# 0  [((100純棉緞檔浴巾), (Tea Zen 韓國玉米鬚茶), 0.70571428571...
# 1  [((1片/包)), (家樂福大比目魚切片(每包淨重約160g), 1.0, 31.1912...
# 2  [((2片/包)), (家樂福大比目魚切片(每包淨重約400g), 1.0, 32.9942...
# 3  [((UCC 114 即溶咖啡), (3點1刻 奶油玉米濃湯-18gx12), 0.6553...
# 4  [((3點1刻經典原味奶茶-20gx15), (讚岐冷凍烏龍麵), 0.7217537942...

# %%
#展開
association_DF = association_DF.explode('ordered_statistics')
association_DF.head()
# Out:
#                           items   support  \
# 0   (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273
# 0   (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273
# 1  (1片/包), 家樂福大比目魚切片(每包淨重約160g)  0.032060
# 1  (1片/包), 家樂福大比目魚切片(每包淨重約160g)  0.032060
# 2  (2片/包), 家樂福大比目魚切片(每包淨重約400g)  0.030308
#
#                                   ordered_statistics
# 0  ((100純棉緞檔浴巾), (Tea Zen 韓國玉米鬚茶), 0.705714285714...
# 0  ((Tea Zen 韓國玉米鬚茶), (100純棉緞檔浴巾), 0.789137380191...
# 1  ((1片/包)), (家樂福大比目魚切片(每包淨重約160g), 1.0, 31.19125...
# 1  ((家樂福大比目魚切片(每包淨重約160g), (1片/包)), 1.0, 31.19125...
# 2  ((2片/包)), (家樂福大比目魚切片(每包淨重約400g), 1.0, 32.99421...

# %%
#再次展開成四個 row 為一個規則
association_DF = association_DF.explode('ordered_statistics')
association_DF.head()
# Out:
#                          items   support ordered_statistics
# 0  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273        (100純棉緞檔浴巾)
# 0  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273   (Tea Zen 韓國玉米鬚茶)
# 0  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273           0.705714
# 0  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273            12.8697
# 0  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273   (Tea Zen 韓國玉米鬚茶)

# %%
# 重製 index 
association_DF.reset_index(drop=True,inplace=True)
association_DF.head()
# Out:
#                          items   support ordered_statistics
# 0  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273        (100純棉緞檔浴巾)
# 1  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273   (Tea Zen 韓國玉米鬚茶)
# 2  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273           0.705714
# 3  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273            12.8697
# 4  (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273   (Tea Zen 韓國玉米鬚茶)

# %%
#創造每條規則的support dataframe
association_DF_copy = association_DF.copy()
for i in range(len(association_DF)):
    if i%4 != 0:
        association_DF_copy.drop(index=i,inplace=True)
association_DF_copy.reset_index(drop=True,inplace=True)
association_DF_copy.head()
# Out:
#                           items   support     ordered_statistics
# 0   (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273            (100純棉緞檔浴巾)
# 1   (Tea Zen 韓國玉米鬚茶, 100純棉緞檔浴巾)  0.043273       (Tea Zen 韓國玉米鬚茶)
# 2  (1片/包), 家樂福大比目魚切片(每包淨重約160g)  0.032060                (1片/包))
# 3  (1片/包), 家樂福大比目魚切片(每包淨重約160g)  0.032060  (家樂福大比目魚切片(每包淨重約160g)
# 4  (2片/包), 家樂福大比目魚切片(每包淨重約400g)  0.030308                (2片/包))

# %%
#創造每條規則的 Dataframe
rule_list = []
association_list = association_DF['ordered_statistics'].tolist()
n = 0
while True:
    if n < len(association_DF)-3:
        tmp_list = association_list[n:n+4]
        rule_list.append(tmp_list)
        n +=4
    else:
        break
associate_df = pd.DataFrame(data = rule_list, columns=['item1','item2','confidence','lift'])
associate_df.head()
# Out:
#                    item1                  item2  confidence       lift
# 0            (100純棉緞檔浴巾)       (Tea Zen 韓國玉米鬚茶)    0.705714  12.869703
# 1       (Tea Zen 韓國玉米鬚茶)            (100純棉緞檔浴巾)    0.789137  12.869703
# 2                (1片/包))  (家樂福大比目魚切片(每包淨重約160g)    1.000000  31.191257
# 3  (家樂福大比目魚切片(每包淨重約160g)                (1片/包))    1.000000  31.191257
# 4                (2片/包))  (家樂福大比目魚切片(每包淨重約400g)    1.000000  32.994220

# %%
# 將規則與Support合併
association_rule_df = pd.concat([associate_df,association_DF_copy['support']],axis=1)
association_rule_df.head()
# Out:
#                    item1                  item2  confidence       lift  \
# 0            (100純棉緞檔浴巾)       (Tea Zen 韓國玉米鬚茶)    0.705714  12.869703
# 1       (Tea Zen 韓國玉米鬚茶)            (100純棉緞檔浴巾)    0.789137  12.869703
# 2                (1片/包))  (家樂福大比目魚切片(每包淨重約160g)    1.000000  31.191257
# 3  (家樂福大比目魚切片(每包淨重約160g)                (1片/包))    1.000000  31.191257
# 4                (2片/包))  (家樂福大比目魚切片(每包淨重約400g)    1.000000  32.994220
#
#     support
# 0  0.043273
# 1  0.043273
# 2  0.032060
# 3  0.032060
# 4  0.030308

# %%
# 把信心度為100%的規則去掉
association_rule_df.drop(association_rule_df[association_rule_df['confidence']==1].index,axis=0, inplace=True)

# %%
# 新增一欄 item2原本的購買率
association_rule_df['item2_original_buy_rate'] = association_rule_df['confidence'] / association_rule_df['lift']

# %%
# show 結果 (以提升度為大小為準則)
association_rule_df.sort_values(by = 'lift', ascending=False).head()
# Out:
#                       item1                   item2  confidence       lift  \
# 136             (現烤月皇酥禮盒8入)    (家樂福超值狗乾糧(牛肉風味)3.5K)    0.836066  18.145484
# 135    (家樂福超值狗乾糧(牛肉風味)3.5K)             (現烤月皇酥禮盒8入)    0.775665  18.145484
# 87   (呂青麥草本精萃洗髮精500ml 韓國進口)           (天命海苔酥(蔬菜口味))    0.757709  17.581319
# 88            (天命海苔酥(蔬菜口味))  (呂青麥草本精萃洗髮精500ml 韓國進口)    0.699187  17.581319
# 170            (桂格鮮榖王堅果多穀飲)      (飛利浦HD4924智慧變頻電磁爐)    0.735294  17.415182
#
#       support  item2_original_buy_rate
# 136  0.035739                 0.046076
# 135  0.035739                 0.042747
# 87   0.030133                 0.043097
# 88   0.030133                 0.039769
# 170  0.039418                 0.042221

# %%
# show 結果 (以信賴度為準則 購買 item1 的條件下, 購買item2的機率)
association_rule_df.sort_values(by = 'confidence', ascending=False).head()
# Out:
#                   item1                            item2  confidence  \
# 171  (飛利浦HD4924智慧變頻電磁爐)                     (桂格鮮榖王堅果多穀飲)    0.933610
# 192  (飛利浦HD4924智慧變頻電磁爐)  (立頓茗閒情100％台灣茶-活綠茶-90g(2.5gx36))    0.892116
# 160          (朵蔓頭皮淨化噴霧)                    (韓國水協-魚板辣炒年糕)    0.886364
# 96             (天仁茉香綠茶)             (美祿巧克力麥芽飲品鐵罐裝 1.5Kg)    0.858065
# 167        (桂格鮮榖王堅果多穀飲)  (立頓茗閒情100％台灣茶-活綠茶-90g(2.5gx36))    0.839869
#
#           lift   support  item2_original_buy_rate
# 171  17.415182  0.039418                 0.053609
# 192  14.933135  0.037666                 0.059741
# 160   7.135915  0.081990                 0.124212
# 96   12.855203  0.046601                 0.066748
# 167  14.058574  0.045025                 0.059741

# %% [markdown]
# # 輸出結果到本地端

# %%
# 結果存入csv檔 (用提升度來存)
# association_rule_df.to_csv('association_rules.csv',encoding='utf_8_sig',index=False)

# %% [markdown]
# # 搜尋我們要的產品(範例:咖啡)

# %%
association_rule_df[association_rule_df['item1'].apply(lambda x : str(x)).str.contains('咖啡')]
# Out:
#                         item1                  item2  confidence       lift  \
# 6              (UCC 114 即溶咖啡)   (3點1刻 奶油玉米濃湯-18gx12)    0.655303  12.594174
# 44             (UCC 114 即溶咖啡)     (【海倫仙度絲】去屑薄荷舒爽洗髮乳)    0.651515  15.117270
# 75               (伯朗曼特寧咖啡3合1)    (舒潔迪士尼盒裝面紙-140PCx5)    0.718147  16.595876
# 79     (星巴克黃金烘焙義式濃縮咖啡膠囊(12顆))  (光泉冷泡茶茶王烏龍-1235mlx12)    0.671233   8.668320
# 130             (家樂福曼特寧風情咖啡豆)         (海太加鈣營養餅-起士口味)    0.665198   5.110298
# 157  (星巴克特選系列-卡布奇諾咖啡(每盒內含4杯))       (沙威隆抗菌潔淨沐浴乳茶樹精油)    0.762115   9.498144
#
#       support  item2_original_buy_rate
# 6    0.030308                 0.052032
# 44   0.030133                 0.043097
# 75   0.032586                 0.043273
# 79   0.042922                 0.077435
# 130  0.052908                 0.130168
# 157  0.030308                 0.080238
